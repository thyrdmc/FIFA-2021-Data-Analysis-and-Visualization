# %% [markdown]
# # **Import**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## **Read Data**

# %%
df = pd.read_csv("players_21.csv")
df.head(2)
# Out:
#    sofifa_id                                         player_url  ...   rcb    rb
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...  ...  52+3  62+3
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...  ...  54+3  61+3
#
# [2 rows x 106 columns]

# %% [markdown]
# ## **Explarotary Data Analysis**

# %% [markdown]
# **Let's Observe on Turkish Footballers**

# %%
def country(x):
    return df[df['nationality'] == x][['short_name', 'overall', 'potential', 'club_name', 'player_positions']]

country('Turkey').head(10)
# Out:
#          short_name  overall  potential              club_name player_positions
# 388      C. Söyüncü       80         85         Leicester City               CB
# 656   H. Çalhanoğlu       79         79                  Milan           LW, CM
# 715        C. Ünder       78         84         Leicester City           RM, RW
# 784       B. Yılmaz       78         78             LOSC Lille               ST
# 904        O. Kabak       77         87          FC Schalke 04               CB
# 926        Z. Çelik       77         83             LOSC Lille               RB
# 935      O. Yokuşlu       77         82               RC Celta          CDM, CM
# 958        U. Çakır       77         81            Trabzonspor               GK
# 1082       M. Günok       77         77  Medipol Başakşehir FK               GK
# 1186     M. Demiral       76         85               Juventus               CB

# %% [markdown]
# **Let's Observe on Club Footballers (Fenerbahçe)**

# %%
def club(x):
    return df[df['club_name'] == x][['short_name', 'player_positions', 'overall', 'nationality', 'age', 'work_rate',
                                    'wage_eur', 'value_eur', 'contract_valid_until']]

club('Fenerbahçe SK')
# Out:
#             short_name player_positions  ...  value_eur contract_valid_until
# 454       Luiz Gustavo          CDM, CB  ...    9500000               2023.0
# 788            J. Sosa          CM, CDM  ...    4300000               2022.0
# 854           F. Novák               LB  ...    8000000               2023.0
# 1345          G. Gönül               RB  ...    2200000               2021.0
# 1359          C. Erkin           LB, LM  ...    5500000               2022.0
# 1460   Garry Rodrigues           LM, RM  ...    7500000               2021.0
# 1726           S. Aziz               CB  ...    6500000               2022.0
# 1982          D. Türüç               RM  ...    7000000               2022.0
# 2213        N. Sangaré               RB  ...    6000000               2022.0
# 2290          N. Dirar       RM, RB, LB  ...    2800000               2022.0
# 2310             Zanka               CB  ...    4600000               2022.0
# ...

# %%
fb = club('Fenerbahçe SK')
fb.shape
# Out:
# (30, 9)

# %%
fb['wage_eur'].describe()
# Out:
# count       30.000000
# mean     33700.000000
# std      18802.329276
# min       1000.000000
# 25%      20000.000000
# 50%      38000.000000
# 75%      46500.000000
# max      68000.000000
# Name: wage_eur, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18944 entries, 0 to 18943
# Columns: 106 entries, sofifa_id to rb
# dtypes: float64(18), int64(44), object(44)
# memory usage: 15.3+ MB

# %%
df["club_name"].value_counts()
# Out:
# Newcastle United          33
# Atalanta                  33
# Crotone                   33
# Fiorentina                33
# Deportivo Alavés          33
#                           ..
# Grêmio                    20
# Llaneros de Guanare       20
# Brisbane Roar             19
# Central Coast Mariners    18
# Melbourne Victory         18
# Name: club_name, Length: 681, dtype: int64

# %%
df.describe().T
# Out:
#                            count           mean  ...        75%       max
# sofifa_id                18944.0  226242.402872  ...  246760.25  258970.0
# age                      18944.0      25.225823  ...      29.00      53.0
# height_cm                18944.0     181.190773  ...     186.00     206.0
# weight_kg                18944.0      75.016892  ...      80.00     110.0
# league_rank              18719.0       1.357070  ...       1.00       4.0
# ...                          ...            ...  ...        ...       ...
# goalkeeping_diving       18944.0      16.446052  ...      14.00      90.0
# goalkeeping_handling     18944.0      16.236486  ...      14.00      92.0
# goalkeeping_kicking      18944.0      16.103357  ...      14.00      93.0
# goalkeeping_positioning  18944.0      16.225982  ...      14.00      91.0
# goalkeeping_reflexes     18944.0      16.551309  ...      14.00      90.0
#
# [62 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# sofifa_id     0
# player_url    0
# short_name    0
# long_name     0
# age           0
#              ..
# lb            0
# lcb           0
# cb            0
# rcb           0
# rb            0
# Length: 106, dtype: int64

# %% [markdown]
# ### **Data Cleaning**

# %%
# Filling the Missing Variables Values for Proper Data Visualization

df['age'].fillna(df['age'].mean(), inplace = True)
df['dob'].fillna(df['dob'][0], inplace = True)
df['height_cm'].fillna(df['height_cm'].mean(), inplace = True)
df['weight_kg'].fillna(df['weight_kg'].mean(), inplace = True)
df['nationality'].fillna(df['nationality'][0], inplace = True)
df['club_name'].fillna(df['club_name'][3000], inplace = True)
df['league_name'].fillna(df['league_name'][3000], inplace = True)
df['league_rank'].fillna(df['league_rank'][3000], inplace = True)
df['overall'].fillna(df['overall'].min(), inplace = True)
# df['player_positions'].fillna(df['player_positions'][3000], inplace = True)
df['preferred_foot'].fillna(df['preferred_foot'][3000], inplace = True)
df['international_reputation'].fillna(df['international_reputation'].mean(), inplace = True)
df['weak_foot'].fillna(df['weak_foot'].mean(), inplace = True)
df['skill_moves'].fillna(df['skill_moves'].mean(), inplace = True)
df['work_rate'].fillna(df['work_rate'][3000], inplace = True)
df['body_type'].fillna(df['body_type'][3000], inplace = True)
df['real_face'].fillna(df['real_face'][3000], inplace = True)
df['release_clause_eur'].fillna(df['release_clause_eur'].mean(), inplace = True)
df['player_tags'].fillna(df['player_tags'][7000], inplace = True)
df['team_position'].fillna(df['team_position'][3], inplace = True)
df['team_jersey_number'].fillna(df['team_jersey_number'][3], inplace = True)
df['loaned_from'].fillna(df['loaned_from'][3], inplace = True)
df['joined'].fillna(df['joined'][3], inplace = True)
df['contract_valid_until'].fillna(df['contract_valid_until'][3000], inplace = True)
df['nation_position'].fillna(df['nation_position'][5], inplace = True)
df['nation_jersey_number'].fillna(df['nation_jersey_number'][5], inplace = True)
df['pace'].fillna(df['pace'].mean(), inplace = True)
df['shooting'].fillna(df['shooting'].mean(), inplace = True)
df['passing'].fillna(df['passing'].mean(), inplace = True)
df['dribbling'].fillna(df['dribbling'].mean(), inplace = True)
df['defending'].fillna(df['defending'].mean(), inplace = True)
df['physic'].fillna(df['physic'].mean(), inplace = True)
df['player_traits'].fillna(df['player_traits'][3000], inplace = True)

# %%
df.isnull().sum()
# Out:
# sofifa_id     0
# player_url    0
# short_name    0
# long_name     0
# age           0
#              ..
# lb            0
# lcb           0
# cb            0
# rcb           0
# rb            0
# Length: 106, dtype: int64

# %%
def defending(df):
    return int(round((df[['defending_marking', 'defending_standing_tackle', 
                               'defending_sliding_tackle']].mean()).mean()))

def general(df):
    return int(round((df[['attacking_heading_accuracy', 'skill_dribbling', 'skill_curve', 
                               'skill_ball_control']].mean()).mean()))

def mental(df):
    return int(round((df[['mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 
                               'mentality_vision','mentality_composure']].mean()).mean()))

def passing(df):
    return int(round((df[['attacking_crossing', 'attacking_short_passing', 
                               'skill_long_passing	']].mean()).mean()))

def mobility(df):
    return int(round((ddfata[['movement_acceleration', 'movement_sprint_speed', 
                               'movement_agility','movement_reactions']].mean()).mean()))
def power(df):
    return int(round((df[['movement_balance', 'power_jumping', 'power_stamina', 
                               'power_strength']].mean()).mean()))

def rating(df):
    return int(round((df[['potential', 'overall']].mean()).mean()))

def shooting(df):
    return int(round((df[['attacking_finishing', 'attacking_volleys	', 'skill_fk_accuracy', 
                               'power_shot_power','shooting', 'mentality_penalties']].mean()).mean()))

# %% [markdown]
# ### **Visualize Data & Preprocessing**

# %%
from os import mkdir

# %%
try:
  mkdir("Plots")
except:
  pass
mypath = "Plots"

# %%
# Comparison of Preferred Foot to Different Players

plt.rcParams['figure.figsize'] = (10, 5)
sns.countplot(df['preferred_foot'], palette="Set3")
plt.title('Most Preferred Foot of the Players', fontsize = 20)
plt.xlabel('Preferred Foot', fontsize = 13)
plt.ylabel('Number of Players', fontsize = 13)
plt.savefig("Plots/Most_Preferred_Foot.png")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df[['short_name', 'international_reputation']].head()
# Out:
#           short_name  international_reputation
# 0           L. Messi                         5
# 1  Cristiano Ronaldo                         5
# 2           J. Oblak                         3
# 3     R. Lewandowski                         4
# 4          Neymar Jr                         5

# %%
# Plotting a Pie Chart to Display the International Reputation of Players

labels = ['1 (Lowest Tier)', '2', '3', '4', '5 (Top Tier)']
sizes = df['international_reputation'].value_counts()
colors = plt.cm.copper(np.linspace(1, 0, 5))
explode = [0.1, 0.1, 0.2, 0.5, 0.9]
plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(sizes, labels = labels, colors = colors, explode = explode, shadow = True)
plt.title('Distribution of International Reputation Ratings of Footballers', fontsize = 20)
plt.legend(title = "Reputation Ratings", loc ="best",)
plt.savefig("Plots/International_Reputation_Ratings.png")
plt.show()

# %%
df[['short_name', 'weak_foot']].head()
# Out:
#           short_name  weak_foot
# 0           L. Messi          4
# 1  Cristiano Ronaldo          4
# 2           J. Oblak          3
# 3     R. Lewandowski          4
# 4          Neymar Jr          5

# %%
# Plotting a Pie Chart to Represent the Share of Degree of Weak Foot Use of Players

labels = ['3', '2', '4', '5 (Highest Rate)', '1 (Lowest Rate)'] 
size = df['weak_foot'].value_counts()
colors = plt.cm.Wistia(np.linspace(0, 1, 5))
explode = [0.05, 0, 0, 0, 0.1]

plt.pie(size, labels = labels, colors = colors, explode = explode, shadow = True, startangle = 90)
plt.title('Distribution of Ability to Use Weak Foot of Footballers', fontsize = 25)
plt.legend(title = "Using Weak Foot Ratings", loc ="best",)
plt.savefig("Plots/Using_Weak_Foot_Ratings.png")
plt.show()

# %%
df.head(2)
# Out:
#    sofifa_id                                         player_url  ...   rcb    rb
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...  ...  52+3  62+3
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...  ...  54+3  61+3
#
# [2 rows x 106 columns]

# %%
df['wage_eur'].value_counts()
# Out:
# 2000      2943
# 500       2790
# 3000      1935
# 1000      1695
# 4000      1156
#           ...
# 560000       1
# 200000       1
# 370000       1
# 280000       1
# 290000       1
# Name: wage_eur, Length: 142, dtype: int64

# %%
# Comparing of Players Wages

import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (15, 5)
sns.distplot(df['wage_eur'], color = 'blue')
plt.xlabel('Wage (Euro)', fontsize = 16)
plt.ylabel('Number of Players', fontsize = 16)
plt.title('Distribution of Players Wages', fontsize = 20)
plt.savefig("Plots/Distribution_of_Players_Wages.png")
plt.show()

# %%
# Distribution of Players Wage by Age

import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (20, 6)
sns.relplot(data=df, x="age", y="wage_eur", hue="age", palette="ch:r=-.5,l=.75")
plt.xlabel('Age', fontsize = 13)
plt.ylabel('Wage (Euro)', fontsize = 13)
plt.title('Distribution of Players Wage by Age', fontsize = 20)
plt.savefig("Plots/Distribution_of_Players_Wages_by_Age.png")
plt.show()

# %%
# Distribution of Players Value (Euro) by Internation Reputation and Preferred Foot Informations

import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (20, 6)
sns.relplot(data=df, x="international_reputation", y="value_eur", hue="preferred_foot", style="preferred_foot", kind="line")
plt.xlabel('International Reputation', fontsize = 13)
plt.ylabel('Value (Eur)', fontsize = 13)
plt.title('Distribution of Players Value (Euro) by Internation Reputation and Preferred Foot Informations', fontsize = 20)
plt.savefig("Plots/Distribution_of_Players_Value_by_Internation_Reputation&Preferred_Foot.png")
plt.show()

# %%
df.head(2)
# Out:
#    sofifa_id                                         player_url  ...   rcb    rb
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...  ...  52+3  62+3
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...  ...  54+3  61+3
#
# [2 rows x 106 columns]

# %%
df['skill_moves'].value_counts()
# Out:
# 2    9134
# 3    6546
# 1    2084
# 4    1125
# 5      55
# Name: skill_moves, dtype: int64

# %%
# Skill Moves Ratings of Players

plt.figure(figsize = (10, 8))
ax = sns.countplot(x = 'skill_moves', data = df, palette = 'pastel')
ax.set_title(label = 'Number of Players on Basis of Their Skill Moves', fontsize = 20)
ax.set_xlabel(xlabel = 'Skill Moves Ratings', fontsize = 16)
ax.set_ylabel(ylabel = 'Number of Players', fontsize = 16)
plt.savefig("Plots/Skill_Moves_Ratings_of_Players.png")
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (20, 6)
sns.relplot(data=df, x="skill_moves", y="overall", hue="preferred_foot", style="preferred_foot", kind="line")
plt.xlabel('Skill Moves Ratings', fontsize = 13)
plt.ylabel('Overall', fontsize = 13)
plt.title('Effect of Skill Moves and Preferred Foot on Players Overall', fontsize = 20)
plt.savefig("Plots/Effect_of_Skill_Moves&Preferred_Foot_on_Overall.png")
plt.show()

# %%
# Distribution of Players on Basis of Height

plt.figure(figsize = (13, 8))
ax = sns.countplot(x = 'height_cm', data = df, linewidth=2, edgecolor=sns.color_palette("dark", 3))
ax.tick_params(axis='x', rotation=90)
ax.set_title(label = 'Distribution of Players on Basis of Height', fontsize = 20)
ax.set_xlabel(xlabel = 'Height (cm)', fontsize = 16)
ax.set_ylabel(ylabel = 'Number of Players', fontsize = 16)
plt.savefig("Plots/Distribution_of_Players_on_Basis_of_Height.png")
plt.show()

# %%
df['weight_kg'].value_counts()
# Out:
# 70     1510
# 75     1458
# 80     1112
# 72     1019
# 78      991
# 74      963
# 73      949
# 77      899
# 76      876
# 68      782
# 79      693
# 71      647
# 82      629
# 69      554
# 65      534
# 83      521
# 81      512
# 67      499
# 84      437
# 85      417
# 66      401
# 64      339
# 86      288
# 88      266
# 63      241
# 87      224
# 62      182
# 90      156
# 60      154
# 89      124
# 61      105
# 91       86
# 92       66
# 93       50
# 58       43
# 59       41
# 94       34
# 95       30
# 55       16
# 96       14
# 57       14
# 98       13
# 56       11
# 97        9
# 100       7
# 103       4
# 54        4
# 102       4
# 99        3
# 101       3
# 104       3
# 52        2
# 53        2
# 50        1
# 110       1
# 107       1
# Name: weight_kg, dtype: int64

# %%
# Distribution of Players on Basis of Body Weight 

plt.figure(figsize = (20, 5))
sns.histplot(x = df['weight_kg'], binwidth=1, kde=True)
plt.title('Distribution of Players on Basis of Body Weight ', fontsize = 20)
plt.xlabel('Body Weights (kg)', fontsize = 16)
plt.ylabel('Number of Players', fontsize = 16)
plt.savefig("Plots/Distribution_of_Players_on_Basis_of_Weight.png")
plt.show()

# %%
df.head(2)
# Out:
#    sofifa_id                                         player_url  ...   rcb    rb
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...  ...  52+3  62+3
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...  ...  54+3  61+3
#
# [2 rows x 106 columns]

# %%
# Distribution of Work Rates of Players

plt.figure(figsize = (15, 7))

sns.countplot(x = 'work_rate', data = df, palette = 'hls')
plt.title('Distribution of Work Rates of Players', fontsize = 20)
plt.xlabel('Work Rates', fontsize = 16)
plt.ylabel('Number of Players', fontsize = 16)
plt.savefig("Plots/Distribution_of_Work_Rates_of_Players.png")
plt.show()

# %%
# Histogram of Different Potential Scores of Players 

x = df.potential
plt.figure(figsize=(12,8))
plt.style.use('seaborn-paper')

ax = sns.distplot(x, bins = 58, kde = False, color = 'y')
ax.set_xlabel(xlabel = "Player's Potential Scores", fontsize = 16)
ax.set_ylabel(ylabel = 'Number of Players', fontsize = 16)
ax.set_title(label = 'Histogram of Players Potential Scores', fontsize = 20)
plt.savefig("Plots/Histogram_of_Players_Potential_Scores.png")
plt.show()

# %%
df.head(2)
# Out:
#    sofifa_id                                         player_url  ...   rcb    rb
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...  ...  52+3  62+3
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...  ...  54+3  61+3
#
# [2 rows x 106 columns]

# %%
# Distribution of the Number of Players by Nationality

plt.style.use('ggplot')
df['nationality'].value_counts().head(80).plot.bar(color = 'blue', figsize = (20, 7))
plt.title('Distribution of the Number of Players by Nationality', fontsize = 30, fontweight = 20)
plt.xlabel('Country')
plt.ylabel('Number of Players')
plt.savefig("Plots/Distribution_of_the_Number_of_Players_by_Nationality.png")
plt.show()

# %%
df.head(1)
# Out:
#    sofifa_id                                         player_url  ...   rcb    rb
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...  ...  52+3  62+3
#
# [1 rows x 106 columns]

# %%
# Selecting Some of Interesting and Important Columns

selected_columns = ['short_name', 'age', 'nationality', 'overall', 'potential', 'club_name', 'value_eur',
                    'wage_eur', 'Special', 'preferred_foot', 'international_reputation', 'weak_foot',
                    'skill_moves', 'work_rate', 'body_type', 'team_position', 'height_cm', 'weight_kg',
                    'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
                    'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
                    'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
                    'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
                    'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
                    'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
                    'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause']

data_selected = pd.DataFrame(df, columns = selected_columns)
data_selected.columns
# Out:
# Index(['short_name', 'age', 'nationality', 'overall', 'potential', 'club_name',
#        'value_eur', 'wage_eur', 'Special', 'preferred_foot',
#        'international_reputation', 'weak_foot', 'skill_moves', 'work_rate',
#        'body_type', 'team_position', 'height_cm', 'weight_kg', 'Finishing',
#        'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
#        'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
plt.rcParams['figure.figsize'] = (20, 7)
plt.style.use('seaborn-dark-palette')

sns.boxenplot(df['overall'], df['age'], hue = df['preferred_foot'], palette = 'Greys')
plt.title('Comparison of Overall Scores and Age with Preferred foot', fontsize = 20)
plt.savefig("Plots/Comparison_of_Overall_Scores&Age_with_Preferred_foot.png")
plt.show()

# %%
df['team_position'].value_counts()
# Out:
# SUB    8065
# RES    3163
# RCB     681
# GK      681
# LCB     681
# ST      677
# RB      553
# LB      553
# RCM     425
# LCM     425
# LM      420
# RM      420
# CAM     286
# RDM     248
# LDM     248
# RS      224
# LS      224
# CDM     181
# LW      170
# RW      170
# CB      128
# LWB      78
# RWB      78
# CM       76
# LAM      25
# RAM      25
# CF       13
# LF       13
# RF       13
# Name: team_position, dtype: int64

# %%
plt.rcParams['figure.figsize'] = (20, 7)
plt.style.use('seaborn-dark-palette')

sns.boxenplot(df['team_position'], df['overall'])
plt.title('Overall Ranges of Players According to Team Position', fontsize = 20)
plt.xlabel('Team Position')
plt.ylabel('Overall')
plt.savefig("Plots/Overall_Ranges_of_Players_According_to_Team_Position.png")
plt.show()

# %%
# Selecting a Sample from the Dataset

data_selected.sample(2)
# Out:
#         short_name  age  ... GKReflexes  Release Clause
# 17531     S. Bowen   19  ...        NaN             NaN
# 15933  T. Abdullah   24  ...        NaN             NaN
#
# [2 rows x 52 columns]

# %%
# Plotting a Correlation Heatmap

plt.rcParams['figure.figsize'] = (200, 75)
sns.heatmap(data_selected[['age', 'nationality', 'overall', 'potential', 'club_name', 'value_eur',
                    'wage_eur', 'preferred_foot', 'international_reputation', 'weak_foot',
                    'skill_moves', 'work_rate', 'body_type', 'team_position', 'height_cm', 'weight_kg'
                    ]].corr(), annot = True)

plt.title('Correlation Heatmap of the Sample Data', fontsize = 50)
plt.savefig("Plots/Correlation_Heatmap_of_the_Sample_Data.png")
plt.show()

# %%
# Best Players per each Position with their Age, Club, and Nationality based on their Overall Scores

df.iloc[df.groupby(df['team_position'])['overall'].idxmax()][['team_position', 'short_name', 'age', 'club_name', 'nationality']].style.background_gradient('Reds')
# Out:
# <style  type="text/css" >
# #T_98975bba_3a19_11ec_874a_0242ac1c0002row0_col2{
#             background-color:  #aa1016;
#             color:  #f1f1f1;
#         }#T_98975bba_3a19_11ec_874a_0242ac1c0002row1_col2,#T_98975bba_3a19_11ec_874a_0242ac1c0002row27_col2{
#             background-color:  #d52221;
#             color:  #f1f1f1;
#         }#T_98975bba_3a19_11ec_874a_0242ac1c0002row2_col2,#T_98975bba_3a19_11ec_874a_0242ac1c0002row8_col2,#T_98975bba_3a19_11ec_874a_0242ac1c0002row14_col2,#T_98975bba_3a19_11ec_874a_0242ac1c0002row25_col2{
#             background-color:  #fb694a;
#             color:  #000000;
#         }#T_98975bba_3a19_11ec_874a_0242ac1c0002row3_col2,#T_98975bba_3a19_11ec_874a_0242ac1c0002row11_col2,#T_98975bba_3a19_11ec_874a_0242ac1c0002row22_col2,#T_98975bba_3a19_11ec_874a_0242ac1c0002row28_col2{
#             background-color:  #bf151b;
#             color:  #f1f1f1;
# ...

# %%
# Best Players from each Positions with their Age, Nationality, Club based on their Potential Scores

df.iloc[df.groupby(df['team_position'])['potential'].idxmax()][['team_position', 'short_name', 'age', 'club_name', 'nationality']].style.background_gradient('Blues')
# Out:
# <style  type="text/css" >
# #T_989fec30_3a19_11ec_874a_0242ac1c0002row0_col2{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_989fec30_3a19_11ec_874a_0242ac1c0002row1_col2,#T_989fec30_3a19_11ec_874a_0242ac1c0002row27_col2{
#             background-color:  #08509b;
#             color:  #f1f1f1;
#         }#T_989fec30_3a19_11ec_874a_0242ac1c0002row2_col2,#T_989fec30_3a19_11ec_874a_0242ac1c0002row8_col2,#T_989fec30_3a19_11ec_874a_0242ac1c0002row14_col2,#T_989fec30_3a19_11ec_874a_0242ac1c0002row25_col2{
#             background-color:  #3181bd;
#             color:  #000000;
#         }#T_989fec30_3a19_11ec_874a_0242ac1c0002row3_col2,#T_989fec30_3a19_11ec_874a_0242ac1c0002row11_col2,#T_989fec30_3a19_11ec_874a_0242ac1c0002row22_col2{
#             background-color:  #084082;
#             color:  #f1f1f1;
#         }#T_989fec30_3a19_11ec_874a_0242ac1c0002row4_col2,#T_989fec30_3a19_11ec_874a_0242ac1c0002row12_col2{
# ...

# %%
# Picking up the Countries with Highest Number of Players to Compare their Overall Scores

df['nationality'].value_counts().head(8).plot.bar(color = 'b', figsize = (20, 7))
plt.title('Distribution of the Countries with Highest Number of Players', fontsize = 30, fontweight = 20)
plt.xlabel('Country')
plt.ylabel('Number of Players')
plt.savefig("Plots/Distribution_of_Countries_with_Highest_Number_of_Players.png")
plt.show()

# %%
# Distribution of Weight of Players from Different Countries

some_countries = ('England', 'Germany', 'Spain', 'France', 'Argentina', 'Brazil', 'Japan', 'Netherlands', "Turkey")
data_countries = df.loc[df['nationality'].isin(some_countries) & df['weight_kg']]

plt.rcParams['figure.figsize'] = (15, 7)
ax = sns.violinplot(x = data_countries['nationality'], y = data_countries['weight_kg'], palette = 'Reds')
ax.set_xlabel(xlabel = 'Country', fontsize = 9)
ax.set_ylabel(ylabel = 'Weight (kg)', fontsize = 9)
ax.set_title(label = 'Distribution of Weight of Players from Different Countries', fontsize = 20)
plt.savefig("Plots/Distribution_of_Weight_of_Players_from_Different_Countries.png")
plt.show()

# %%
# Distribution of Overall Scores of Players from Different Countries

some_countries = ('England', 'Germany', 'Spain', 'France', 'Argentina', 'Brazil', 'Japan', 'Netherlands', "Turkey")
data_countries = df.loc[df['nationality'].isin(some_countries) & df['overall']]

plt.rcParams['figure.figsize'] = (15, 7)
ax = sns.barplot(x = data_countries['nationality'], y = data_countries['overall'], palette = 'rocket')
ax.set_xlabel(xlabel = 'Country', fontsize = 9)
ax.set_ylabel(ylabel = 'Overall Score', fontsize = 9)
ax.set_title(label = 'Distribution of Overall Scores of Players from Different Countries', fontsize = 20)
plt.savefig("Plots/Distribution_of_Overall_Scores_of_Players_from_Different_Countries.png")
plt.show()

# %%
# Distribution of Internatioal Repuatation of Players from Different Countries

some_countries = ('England', 'Germany', 'Spain', 'France', 'Argentina', 'Brazil', 'Japan', 'Netherlands', "Turkey")
data_countries = df.loc[df['nationality'].isin(some_countries) & df['international_reputation']]

plt.rcParams['figure.figsize'] = (15, 7)
ax = sns.violinplot(x = data_countries['nationality'], y = data_countries['international_reputation'])
ax.set_xlabel(xlabel = 'Country', fontsize = 9)
ax.set_ylabel(ylabel = 'International Reputation', fontsize = 9)
ax.set_title(label = 'Distribution of Internatioal Repuatation of Players from Different Countries', fontsize = 15)
plt.savefig("Plots/Distribution_of_Internatioal_Repuatation_of_Players_from_Different_Countries.png")
plt.show()

# %%
# Distribution of Overall Score in Some Popular Clubs

some_clubs = ('FC Barcelona', 'Real Madrid', 'Atlético Madrid', 'Juventus', 'Inter', 'Milan', 'Manchestar City',
             'Liverpool', 'Arsenal', 'Manchester United', 'Chelsea', 'FC Bayern München','Borussia Dortmund' , 
             'Paris Saint-Germain', 'Ajax', 'PSV', 'Shakhtar Donetsk', 'Dynamo Kyiv', 'Fenerbahçe SK', 'Galatasaray SK')

data_clubs = df.loc[df['club_name'].isin(some_clubs) & df['overall']]

plt.rcParams['figure.figsize'] = (15, 8)
ax = sns.boxplot(x = data_clubs['club_name'], y = data_clubs['overall'], palette = 'rocket')
ax.set_xlabel(xlabel = 'Some Popular Clubs', fontsize = 9)
ax.set_ylabel(ylabel = 'Overall Score', fontsize = 9)
ax.set_title(label = 'Distribution of Overall Score in Some Popular Clubs', fontsize = 20)
plt.xticks(rotation = 90)
plt.savefig("Plots/Distribution_of_Overall_Score_in_Some_Popular_Clubs.png")
plt.show()

# %%
# Distribution of Ages in Some Popular Clubs

some_clubs = ('FC Barcelona', 'Real Madrid', 'Atlético Madrid', 'Juventus', 'Inter', 'Milan', 'Manchestar City',
             'Liverpool', 'Arsenal', 'Manchester United', 'Chelsea', 'FC Bayern München','Borussia Dortmund' , 
             'Paris Saint-Germain', 'Ajax', 'PSV', 'Shakhtar Donetsk', 'Dynamo Kyiv', 'Fenerbahçe SK', 'Galatasaray SK')

data_club = df.loc[df['club_name'].isin(some_clubs) & df['age']]

plt.rcParams['figure.figsize'] = (15, 8)
ax = sns.violinplot(x = 'club_name', y = 'age', data = data_club, palette = 'cividis')
ax.set_xlabel(xlabel = 'Some Popular Clubs', fontsize = 10)
ax.set_ylabel(ylabel = 'Age', fontsize = 10)
ax.set_title(label = 'Distribution of Ages in Some Popular Clubs', fontsize = 20)
plt.xticks(rotation = 90)
plt.savefig("Plots/Distribution_of_Ages_in_Some_Popular_Clubs.png")
plt.show()

# %%
df.head(2)
# Out:
#    sofifa_id                                         player_url  ...   rcb    rb
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...  ...  52+3  62+3
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...  ...  54+3  61+3
#
# [2 rows x 106 columns]

# %%
# Distribution of International Reputation in Some Popular Clubs

some_clubs = ('FC Barcelona', 'Real Madrid', 'Atlético Madrid', 'Juventus', 'Inter', 'Milan', 'Manchestar City',
             'Liverpool', 'Arsenal', 'Manchester United', 'Chelsea', 'FC Bayern München','Borussia Dortmund' , 
             'Paris Saint-Germain', 'Ajax', 'Fenerbahçe SK', 'Galatasaray SK')

data_club = df.loc[df['club_name'].isin(some_clubs) & df['international_reputation']]

plt.rcParams['figure.figsize'] = (16, 8)
ax = sns.violinplot(x = 'club_name', y = 'international_reputation', data = data_club, palette = 'cividis')
ax.set_xlabel(xlabel = 'Some Popular Clubs', fontsize = 10)
ax.set_ylabel(ylabel = 'International Reputation', fontsize = 10)
ax.set_title(label = "Distribution of Players' International Reputation in some Popular Clubs", fontsize = 20)
plt.xticks(rotation = 90)
plt.savefig("Plots/Distribution_of_Players'_International_Reputation_in_Some_Popular_Clubs.png")
plt.show()

# %%
# Finding 15 Youngest Players from the Dataset

df.sort_values('age', ascending = True)[['short_name', 'age', 'club_name', 'nationality']].head(15).style.background_gradient('inferno_r')
# Out:
# <style  type="text/css" >
# #T_9b50a62c_3a19_11ec_874a_0242ac1c0002row0_col1,#T_9b50a62c_3a19_11ec_874a_0242ac1c0002row1_col1,#T_9b50a62c_3a19_11ec_874a_0242ac1c0002row2_col1,#T_9b50a62c_3a19_11ec_874a_0242ac1c0002row3_col1,#T_9b50a62c_3a19_11ec_874a_0242ac1c0002row4_col1,#T_9b50a62c_3a19_11ec_874a_0242ac1c0002row5_col1,#T_9b50a62c_3a19_11ec_874a_0242ac1c0002row6_col1,#T_9b50a62c_3a19_11ec_874a_0242ac1c0002row7_col1,#T_9b50a62c_3a19_11ec_874a_0242ac1c0002row8_col1,#T_9b50a62c_3a19_11ec_874a_0242ac1c0002row9_col1,#T_9b50a62c_3a19_11ec_874a_0242ac1c0002row10_col1,#T_9b50a62c_3a19_11ec_874a_0242ac1c0002row11_col1,#T_9b50a62c_3a19_11ec_874a_0242ac1c0002row12_col1,#T_9b50a62c_3a19_11ec_874a_0242ac1c0002row13_col1,#T_9b50a62c_3a19_11ec_874a_0242ac1c0002row14_col1{
#             background-color:  #fcffa4;
#             color:  #000000;
# ...

# %%
# Finding 15 Eldest Players from the Dataset

df.sort_values('age', ascending = False)[['short_name', 'age', 'club_name', 'nationality']].head(15).style.background_gradient('inferno_r')
# Out:
# <style  type="text/css" >
# #T_9b6814ec_3a19_11ec_874a_0242ac1c0002row0_col1{
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }#T_9b6814ec_3a19_11ec_874a_0242ac1c0002row1_col1,#T_9b6814ec_3a19_11ec_874a_0242ac1c0002row2_col1{
#             background-color:  #fbb61a;
#             color:  #000000;
#         }#T_9b6814ec_3a19_11ec_874a_0242ac1c0002row3_col1,#T_9b6814ec_3a19_11ec_874a_0242ac1c0002row4_col1,#T_9b6814ec_3a19_11ec_874a_0242ac1c0002row5_col1,#T_9b6814ec_3a19_11ec_874a_0242ac1c0002row6_col1,#T_9b6814ec_3a19_11ec_874a_0242ac1c0002row7_col1{
#             background-color:  #f4df53;
#             color:  #000000;
# ...

# %%
# Checking the Head of the Joined Column

df['joined'].head()
# Out:
# 0    2004-07-01
# 1    2018-07-10
# 2    2014-07-16
# 3    2014-07-01
# 4    2017-08-03
# Name: joined, dtype: object

# %%
# The Longest Membership in the Club

import datetime

now = datetime.datetime.now()
df['join_year'] = df['joined'].dropna().map(lambda x: x.split('-')[0].split(' ')[0])
df['years_of_member'] = (df['join_year'].dropna().map(lambda x: now.year - int(x))).astype('int')
membership = df[['short_name', 'club_name', 'years_of_member']].sort_values(by = 'years_of_member', ascending = False).head(10)
membership.set_index('short_name')
membership
# Out:
#           short_name           club_name  years_of_member
# 10334    H. Sogahata     Kashima Antlers               23
# 6920         Y. Endo         Gamba Osaka               20
# 10333   D. Lewington  Milton Keynes Dons               19
# 433      I. Akinfeev     PFC CSKA Moscow               19
# 5044   Kim Kwang Suk     Pohang Steelers               19
# 13667      D. Zibung           FC Luzern               18
# 6972     K. Nakamura   Kawasaki Frontale               18
# 15367     M. McNulty           Cork City               18
# 4204     P. Karlsson                 AIK               18
# 11520  M. Bloomfield   Wycombe Wanderers               18

# %%
# Defining the Features of Players

player_features = ('movement_acceleration', 'mentality_aggression', 'movement_agility', 
                   'movement_balance', 'skill_ball_control', 'mentality_composure', 
                   'attacking_crossing', 'skill_dribbling', 'skill_fk_accuracy', 
                   'attacking_finishing', 'goalkeeping_diving', 'goalkeeping_handling', 
                   'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes', 
                   'attacking_heading_accuracy', 'mentality_interceptions', 'power_jumping', 
                   'skill_long_passing', 'power_long_shots', 'defending_marking', 'mentality_penalties')

# Top Four Features for Every Position

for i, val in df.groupby(df['team_position'])[player_features].mean().iterrows():
    print('Position {}: {}, {}, {}'.format(i, *tuple(val.nlargest(4).index)))
# Out:
# Position CAM: movement_agility, movement_balance, skill_ball_control
# Position CB: mentality_aggression, power_jumping, attacking_heading_accuracy
# Position CDM: mentality_aggression, skill_ball_control, skill_long_passing
# Position CF: movement_balance, skill_ball_control, skill_dribbling
# Position CM: movement_balance, movement_agility, skill_ball_control
# Position GK: goalkeeping_reflexes, goalkeeping_diving, goalkeeping_positioning
# Position LAM: movement_agility, movement_acceleration, movement_balance
# Position LB: movement_acceleration, movement_balance, movement_agility
# Position LCB: power_jumping, mentality_aggression, attacking_heading_accuracy
# Position LCM: movement_balance, movement_agility, skill_ball_control
# Position LDM: skill_ball_control, movement_balance, skill_long_passing
# Position LF: movement_agility, movement_balance, movement_acceleration
# Position LM: movement_acceleration, movement_agility, movement_balance
# ...

# %%
from math import pi

idx = 1
plt.figure(figsize=(15,45))
for position_name, features in df.groupby(df['team_position'])[player_features].mean().iterrows():
    top_features = dict(features.nlargest(5))
    
    # Number of Variable
    categories=top_features.keys()
    N = len(categories)

    # We will plot the first row of the data frame.
    values = list(top_features.values())
    values += values[:1]

    # Calculating Angle of Each Axis in the Plot (Plot / Number of Variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    ax = plt.subplot(9, 3, idx, polar=True)

    plt.xticks(angles[:-1], categories, color='grey', size=8)

    ax.set_rlabel_position(0)
    plt.yticks([25,50,75], ["25","50","75"], color="grey", size=7)
    plt.ylim(0,100)
    
    plt.subplots_adjust(hspace = 0.5)
    
    # Plot Data
    ax.plot(angles, values, linewidth=1, linestyle='solid')

    # Fill Area
    ax.fill(angles, values, 'b', alpha=0.1)
    
    plt.title(position_name, size=11, y=1.1)

    idx += 1

    if(idx == 28):
      break;
plt.savefig("Plots/Relationship_Between_Player_Positions&Features.png")

# %%
# Top 10 left Footed Footballers
df[df['preferred_foot'] == 'Left'][['short_name', 'age', 'club_name', 'nationality']].head(10).style.background_gradient('Blues')
# Out:
# <style  type="text/css" >
# #T_9eaee75c_3a19_11ec_874a_0242ac1c0002row0_col1,#T_9eaee75c_3a19_11ec_874a_0242ac1c0002row9_col1{
#             background-color:  #1764ab;
#             color:  #f1f1f1;
#         }#T_9eaee75c_3a19_11ec_874a_0242ac1c0002row1_col1,#T_9eaee75c_3a19_11ec_874a_0242ac1c0002row2_col1{
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }#T_9eaee75c_3a19_11ec_874a_0242ac1c0002row3_col1,#T_9eaee75c_3a19_11ec_874a_0242ac1c0002row4_col1,#T_9eaee75c_3a19_11ec_874a_0242ac1c0002row5_col1,#T_9eaee75c_3a19_11ec_874a_0242ac1c0002row6_col1{
#             background-color:  #e3eef9;
#             color:  #000000;
#         }#T_9eaee75c_3a19_11ec_874a_0242ac1c0002row7_col1{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_9eaee75c_3a19_11ec_874a_0242ac1c0002row8_col1{
#             background-color:  #08306b;
#             color:  #f1f1f1;
# ...

# %%
# Top 10 Right Footed Footballers

df[df['preferred_foot'] == 'Right'][['short_name', 'age', 'club_name', 'nationality']].head(10).style.background_gradient('Blues')
# Out:
# <style  type="text/css" >
# #T_9eb5e958_3a19_11ec_874a_0242ac1c0002row0_col1{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_9eb5e958_3a19_11ec_874a_0242ac1c0002row1_col1,#T_9eb5e958_3a19_11ec_874a_0242ac1c0002row8_col1{
#             background-color:  #89bedc;
#             color:  #000000;
#         }#T_9eb5e958_3a19_11ec_874a_0242ac1c0002row2_col1{
#             background-color:  #2b7bba;
#             color:  #000000;
#         }#T_9eb5e958_3a19_11ec_874a_0242ac1c0002row3_col1,#T_9eb5e958_3a19_11ec_874a_0242ac1c0002row6_col1,#T_9eb5e958_3a19_11ec_874a_0242ac1c0002row7_col1,#T_9eb5e958_3a19_11ec_874a_0242ac1c0002row9_col1{
#             background-color:  #6aaed6;
#             color:  #000000;
#         }#T_9eb5e958_3a19_11ec_874a_0242ac1c0002row4_col1{
#             background-color:  #539ecd;
#             color:  #000000;
#         }#T_9eb5e958_3a19_11ec_874a_0242ac1c0002row5_col1{
#             background-color:  #f7fbff;
# ...

# %%
# Comparing the Performance of Left-Footed and Right-Footed Footballers
# Ball Control vs Dribbling

sns.lmplot(x = 'skill_ball_control', y = 'skill_dribbling', data = df, col = 'preferred_foot')
plt.savefig("Plots/Comparing_the_Performance_of_Left_Footed&Right_Footed_Footballers.png")
plt.show()

# %%
# Visualizing Clubs with Maximum Number of Different Countries

df.groupby(df['club_name'])['nationality'].nunique().sort_values(ascending = False).head(10).plot.bar()
plt.title('Visualizing Clubs with Maximum Number of Different Countries', fontsize = 20, fontweight = 15)
plt.xlabel('Club Name')
plt.ylabel('Highest Number of Players from Different Countries')
plt.savefig("Plots/Visualizing_Clubs_with_Maximum_Number_of_Different_Countries.png")
plt.show()

# %%
# Visualizing Clubs with Minimum Number of Different Countries

df.groupby(df['club_name'])['nationality'].nunique().sort_values(ascending = True).head(10)
# Out:
# club_name
# Oceânico FC               1
# Atlético Mineiro          1
# Botafogo                  1
# Shelbourne FC             1
# São Paulo                 1
# Bahia                     1
# River Plate Montevideo    1
# Club Atlético Tigre       1
# Vasco da Gama             1
# Flamengo                  1
# Name: nationality, dtype: int64

# %%
def Player_data(x):
    return df.loc[x,:]

x = Player_data(0)  #lionel messi, id = 0.
pd.set_option('display.max_rows', 200)
x = pd.DataFrame(x)
print(x)
# Out:
#                                                                             0
# sofifa_id                                                              158023
# player_url                  https://sofifa.com/player/158023/lionel-messi/...
# short_name                                                           L. Messi
# long_name                                      Lionel Andrés Messi Cuccittini
# age                                                                        33
# dob                                                                1987-06-24
# height_cm                                                                 170
# weight_kg                                                                  72
# nationality                                                         Argentina
# club_name                                                        FC Barcelona
# league_name                                            Spain Primera Division
# ...
